# %%
#importing libraries and basic libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

loadinf_dt=sns.load_dataset('titanic')
loadinf_dt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0     3.0    male  22.0    1.0    0.0   7.2500        S   Third
# 1           1     1.0  female  38.0    1.0    0.0  71.2833        C   First
# 2           1     3.0  female  26.0    0.0    0.0   7.9250        S   Third
# 3           1     1.0  female  35.0    1.0    0.0  53.1000        S   First
# 4           0     3.0    male  35.0    0.0    0.0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 598         0     3.0    male   NaN    0.0    0.0   7.2250        C   Third
# 599         1     1.0    male  49.0    1.0    0.0  56.9292        C   First
# 600         1     2.0  female  24.0    2.0    1.0  27.0000        S  Second
# 601         0     3.0    male   NaN    0.0    0.0   7.8958        S   Third
# 602         0     NaN     NaN   NaN    NaN    NaN      NaN      NaN     NaN
#
#        who adult_male deck  embark_town alive  alone
# 0      man       True  NaN  Southampton    no  False
# 1    woman      False    C    Cherbourg   yes  False
# 2    woman      False  NaN  Southampton   yes   True
# 3    woman      False    C  Southampton   yes  False
# 4      man       True  NaN  Southampton    no   True
# ..     ...        ...  ...          ...   ...    ...
# 598    man       True  NaN    Cherbourg    no   True
# 599    man       True    A    Cherbourg   yes  False
# 600  woman      False  NaN  Southampton   yes  False
# 601    man       True  NaN  Southampton    no   True
# 602    NaN        NaN  NaN          NaN   NaN    NaN
#
# [603 rows x 15 columns]

# %%
#using some function like head,tail,shape and column
#first 5 rows
print(loadinf_dt.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0     3.0    male  22.0    1.0    0.0   7.2500        S  Third
# 1         1     1.0  female  38.0    1.0    0.0  71.2833        C  First
# 2         1     3.0  female  26.0    0.0    0.0   7.9250        S  Third
# 3         1     1.0  female  35.0    1.0    0.0  53.1000        S  First
# 4         0     3.0    male  35.0    0.0    0.0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
print(loadinf_dt.tail()) # last 5 rows of dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 598         0     3.0    male   NaN    0.0    0.0   7.2250        C   Third
# 599         1     1.0    male  49.0    1.0    0.0  56.9292        C   First
# 600         1     2.0  female  24.0    2.0    1.0  27.0000        S  Second
# 601         0     3.0    male   NaN    0.0    0.0   7.8958        S   Third
# 602         0     NaN     NaN   NaN    NaN    NaN      NaN      NaN     NaN
#
#        who adult_male deck  embark_town alive  alone
# 598    man       True  NaN    Cherbourg    no   True
# 599    man       True    A    Cherbourg   yes  False
# 600  woman      False  NaN  Southampton   yes  False
# 601    man       True  NaN  Southampton    no   True
# 602    NaN        NaN  NaN          NaN   NaN    NaN

# %%
print(loadinf_dt.shape) #shape of dataset
# Out:
# (603, 15)

# %%
loadinf_dt.columns  #which are column present there
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#using describe function tosee mean ,mode,median,IQR ETC things
loadinf_dt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  603.000000  602.000000  475.000000  602.000000  602.000000  602.000000
# mean     0.393035    2.308970   29.770526    0.539867    0.375415   31.798200
# std      0.488830    0.834501   14.522232    1.097223    0.773044   46.219945
# min      0.000000    1.000000    0.750000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   21.000000    0.000000    0.000000    7.925000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.500000
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   30.500000
# max      1.000000    3.000000   71.000000    8.000000    5.000000  512.329200

# %%
#using isnullsum function to see column with no. of null values
loadinf_dt.isnull().sum()
# Out:
# survived         0
# pclass           1
# sex              1
# age            128
# sibsp            1
# parch            1
# fare             1
# embarked         2
# class            1
# who              1
# adult_male       1
# deck           467
# embark_town      2
# alive            1
# alone            1
# dtype: int64

# %%
#fiiling missing values
#age and deck
newdt=loadinf_dt
newdt['age'].fillna(newdt['age'].mean(),inplace=True)

# Check if 'unknown' is already a category
if 'unknown' not in newdt['deck'].cat.categories:
  # Add 'unknown' to the categories of the 'deck' column if it doesn't exist
  newdt['deck'] = newdt['deck'].cat.add_categories('unknown')

# Now you can fill the missing values with 'unknown'
newdt['deck'].fillna('unknown', inplace=True)
newdt['embark_town'].fillna('sanfransisco',inplace=True)
newdt['embarked'].fillna('S',inplace=True)

newdt
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_22284\3072379220.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdt['age'].fillna(newdt['age'].mean(),inplace=True)
# C:\Users\piyus\AppData\Local\Temp\ipykernel_22284\3072379220.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdt['deck'].fillna('unknown', inplace=True)
# C:\Users\piyus\AppData\Local\Temp\ipykernel_22284\3072379220.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdt['embark_town'].fillna('sanfransisco',inplace=True)
# C:\Users\piyus\AppData\Local\Temp\ipykernel_22284\3072379220.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdt['embarked'].fillna('S',inplace=True)
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0     3.0    male  22.000000    1.0    0.0   7.2500        S
# 1           1     1.0  female  38.000000    1.0    0.0  71.2833        C
# 2           1     3.0  female  26.000000    0.0    0.0   7.9250        S
# 3           1     1.0  female  35.000000    1.0    0.0  53.1000        S
# 4           0     3.0    male  35.000000    0.0    0.0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 598         0     3.0    male  29.770526    0.0    0.0   7.2250        C
# 599         1     1.0    male  49.000000    1.0    0.0  56.9292        C
# 600         1     2.0  female  24.000000    2.0    1.0  27.0000        S
# 601         0     3.0    male  29.770526    0.0    0.0   7.8958        S
# 602         0     NaN     NaN  29.770526    NaN    NaN      NaN        S
#
#       class    who adult_male     deck   embark_town alive  alone
# 0     Third    man       True  unknown   Southampton    no  False
# 1     First  woman      False        C     Cherbourg   yes  False
# 2     Third  woman      False  unknown   Southampton   yes   True
# 3     First  woman      False        C   Southampton   yes  False
# 4     Third    man       True  unknown   Southampton    no   True
# ..      ...    ...        ...      ...           ...   ...    ...
# 598   Third    man       True  unknown     Cherbourg    no   True
# 599   First    man       True        A     Cherbourg   yes  False
# 600  Second  woman      False  unknown   Southampton   yes  False
# 601   Third    man       True  unknown   Southampton    no   True
# 602     NaN    NaN        NaN  unknown  sanfransisco   NaN    NaN
#
# [603 rows x 15 columns]

# %%
newdt.isnull().sum()
# Out:
# survived       0
# pclass         1
# sex            1
# age            0
# sibsp          1
# parch          1
# fare           1
# embarked       0
# class          1
# who            1
# adult_male     1
# deck           0
# embark_town    0
# alive          1
# alone          1
# dtype: int64

# %%
box1=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot with outliers')
plt.show()

# %%
#here handling outliers
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()

# %%
#here handling outliers
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()

# %%
#here handling outliers
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()

# %%
#here handling outliers
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()
