# %%
import pandas as pd
df = pd.read_csv('Sales.csv')
print(df)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26   November  2013            19     Youth (<25)
# 1      2015-11-26   26   November  2015            19     Youth (<25)
# 2      2014-03-23   23      March  2014            49  Adults (35-64)
# 3      2016-03-23   23      March  2016            49  Adults (35-64)
# 4      2014-05-15   15        May  2014            47  Adults (35-64)
# ...           ...  ...        ...   ...           ...             ...
# 93122  2014-03-07    7      March  2014            20     Youth (<25)
# 93123  2014-03-07    7      March  2014            20     Youth (<25)
# 93124  2016-03-07    7      March  2016            20     Youth (<25)
# 93125  2016-03-07    7      March  2016            20     Youth (<25)
# 93126  2013-09-26   26  September  2013            22     Youth (<25)
#
#       Customer_Gender    Country              State Product_Category  \
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.tail()
# Out:
#              Date  Day    Month  Year  Customer_Age    Age_Group  \
# 23628  2013-10-31   31  October  2013            23  Youth (<25)
# 23629  2015-10-31   31  October  2015            23  Youth (<25)
# 23630  2014-04-06    6    April  2014            23  Youth (<25)
# 23631  2016-04-06    6    April  2016            23  Youth (<25)
# 23632  2014-06-11   11     June  2014            23  Youth (<25)
#
#       Customer_Gender        Country       State Product_Category  \
# 23628               F  United States  Washington      Accessories
# 23629               F  United States  Washington      Accessories
# 23630               F  United States  Washington      Accessories
# 23631               F  United States  Washington      Accessories
# 23632               F  United States  Washington      Accessories
#
#       Sub_Category                Product  Order_Quantity  Unit_Cost  \
# 23628      Fenders  Fender Set - Mountain              22          8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23633 entries, 0 to 23632
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              23633 non-null  object
#  1   Day               23633 non-null  int64
#  2   Month             23633 non-null  object
#  3   Year              23633 non-null  int64
#  4   Customer_Age      23633 non-null  int64
#  5   Age_Group         23633 non-null  object
#  6   Customer_Gender   23633 non-null  object
#  7   Country           23633 non-null  object
#  8   State             23633 non-null  object
#  9   Product_Category  23633 non-null  object
#  10  Sub_Category      23633 non-null  object
#  11  Product           23633 non-null  object
#  12  Order_Quantity    23633 non-null  int64
#  13  Unit_Cost         23633 non-null  int64
#  14  Unit_Price        23633 non-null  int64
#  15  Profit            23633 non-null  int64
# ...

# %%
df.shape
# Out:
# (23633, 18)

# %%
#random 5 rows
df.sample(5)
# Out:
#              Date  Day    Month  Year  Customer_Age             Age_Group  \
# 2821   2014-03-24   24    March  2014            35        Adults (35-64)
# 22549  2016-01-12   12  January  2016            28  Young Adults (25-34)
# 7135   2013-08-25   25   August  2013            62        Adults (35-64)
# 7826   2014-05-17   17      May  2014            46        Adults (35-64)
# 10975  2014-05-30   30      May  2014            45        Adults (35-64)
#
#       Customer_Gender        Country             State Product_Category  \
# 2821                M         Canada  British Columbia      Accessories
# 22549               M      Australia   New South Wales      Accessories
# 7135                M  United States        California      Accessories
# 7826                M  United States        California      Accessories
# 10975               F  United States        California      Accessories
#
#             Sub_Category                Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.describe()
# Out:
#                 Day          Year  Customer_Age  Order_Quantity     Unit_Cost  \
# count  23633.000000  23633.000000  23633.000000    23633.000000  23633.000000
# mean      15.524521   2014.580967     35.915246       14.904075      5.629840
# std        8.843315      1.115103     10.902072        8.723508     10.081674
# min        1.000000   2013.000000     17.000000        1.000000      2.000000
# 25%        8.000000   2014.000000     28.000000        7.000000      2.000000
# 50%       15.000000   2014.000000     35.000000       15.000000      3.000000
# 75%       23.000000   2016.000000     43.000000       22.000000      7.000000
# max       31.000000   2016.000000     87.000000       32.000000     59.000000
#
#          Unit_Price        Profit          Cost       Revenue
# count  23633.000000  23633.000000  23633.000000  23632.000000
# mean      13.168112     68.136885     66.670249    134.810680
# std       27.112657    127.584077     91.611555    212.289324
# ...

# %%
df.dtypes
# Out:
# Date                 object
# Day                   int64
# Month                object
# Year                  int64
# Customer_Age          int64
# Age_Group            object
# Customer_Gender      object
# Country              object
# State                object
# Product_Category     object
# Sub_Category         object
# Product              object
# Order_Quantity        int64
# Unit_Cost             int64
# Unit_Price            int64
# Profit                int64
# Cost                  int64
# Revenue             float64
# dtype: object

# %%
cat=[]
num=[]
for column in df.columns:
  if df[column].nunique()>10:
    num.append(column)
  else:
    cat.append(column)

# %%
cat
# Out:
# ['Year',
#  'Age_Group',
#  'Customer_Gender',
#  'Country',
#  'Product_Category',
#  'Sub_Category',
#  'Product',
#  'Unit_Cost',
#  'Unit_Price']

# %%
num
# Out:
# ['Date',
#  'Day',
#  'Month',
#  'Customer_Age',
#  'State',
#  'Order_Quantity',
#  'Profit',
#  'Cost',
#  'Revenue']

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Sales.csv')
df.hist(bins=20, figsize=(15, 10), grid=False)
plt.suptitle('Histograms of All Numeric Columns')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Sales.csv')
df.head()
plt.figure(figsize=(30, 20))
x = df['Profit']
y = df['Year']

plt.scatter(x, y)
plt.show()

# %%
import seaborn as sns
#find aggregate sales among Age_Group (categorical column)
#sns.countplot(df['Age_Group'])
sns.countplot(df['Age_Group'])
# Out:
# <Axes: xlabel='count', ylabel='Age_Group'>

# %%
df['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)          11844
# Young Adults (25-34)     7924
# Youth (<25)              3741
# Seniors (64+)             124
# Name: count, dtype: int64

# %%
df['Age_Group'].value_counts().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
#find (categorical)
df['Product_Category'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category'>

# %%
#(numerical column)
#sns.displot(df['Cost'])
sns.distplot(df['Cost'])
# Out:
# <Axes: xlabel='Cost', ylabel='Density'>

# %%
df['Cost'].skew()
# Out:
# 5.772796443976097

# %%
#(numerical)
sns.distplot(df['Revenue'])
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
df['Revenue'].skew()
# Out:
# 7.1925785306857435

# %%
sns.boxplot(df['Customer_Age'])
# Out:
# <Axes: ylabel='Customer_Age'>

# %%
import numpy as np
x = df['Profit'],
y = df['Revenue']

matrix = np.corrcoef(x, y)
print(matrix)
# Out:
# [[ 1. nan]
#  [nan nan]]

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Sales.csv')
numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr(method='pearson')

print('Correlation matrix:\n', corr)
# Out:
# Correlation matrix:
#                       Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.003895     -0.016419        0.002669   0.013351
# Year           -0.003895  1.000000      0.016707       -0.024203  -0.014249
# Customer_Age   -0.016419  0.016707      1.000000       -0.009410   0.022355
# Order_Quantity  0.002669 -0.024203     -0.009410        1.000000  -0.196004
# Unit_Cost       0.013351 -0.014249      0.022355       -0.196004   1.000000
# Unit_Price      0.012789 -0.015097      0.025028       -0.199868   0.990363
# Profit          0.015212 -0.018758      0.035491        0.145459   0.672043
# Cost            0.014863 -0.021709      0.023363        0.266090   0.678706
# Revenue         0.015548 -0.020651      0.031394        0.202238   0.696801
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.012789  0.015212  0.014863  0.015548
# Year             -0.015097 -0.018758 -0.021709 -0.020651
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Sales.csv')
numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr(method='pearson')
plt.figure(figsize=(5, 5), dpi=500)

sns.heatmap(corr, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm')
plt.show()
